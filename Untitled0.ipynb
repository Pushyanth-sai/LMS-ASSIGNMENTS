# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushyanth-sai/LMS-ASSIGNMENTS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Define the text
text = 'data science machine learning artificial intelligence'

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the generated WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis numbers and ticks
plt.show()

# Save the WordCloud as an image file
wordcloud.to_file('wordcloud.png')
